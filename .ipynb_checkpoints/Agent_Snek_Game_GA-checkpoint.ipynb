# %% [markdown]
# # Solving Snake with Genetic Algorithm

# %%
#Graphics from https://opengameart.org/content/snake-game-assets

#1 FIX MUTATION!
#2 Lean back and have a beer

# %% [markdown]
# # Agent Snek observing environment
# <img src="observemodel.png" style="width: 75%">

# %% [markdown]
# # From Observation to  Action
# <img src="think_to_action.png">

# %% [markdown]
# # Flowchart of the Genetic Algorithm
# <img src="algo.png" style="width: 80%">

# %% [markdown]
# # Imports

# %%
import pygame
import sys
import random
from pygame.math import Vector2
import numpy as np
import math

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
import time
# Out:
# pygame 2.0.0.dev6 (SDL 2.0.10, python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # The game
# The three below classes keep track of everthing related to the game, it's components, states, positions and scores.
# ## Snake Class
# Instantiates with body, which is a list of 2d-Vectors with positions. Also keeps track if Snake is alive, adds another 2d-vector to the body list upon collision with a Donut, draws different PNG:s depending on direction of Snake and moves the snake upon taking action.
# ## Donut Class
# Holds positional recordings of current Donut, draws it and randomizes a new donut upon collision with Snake.
# ## Main Class
# Draws and updates the game, also holds track of scores, collisions, gamestates and the observing/thinking for the Snake object. Initiates with a Snake and Donut object.

# %%
cell_size = 40
cell_number = 10


class SNAKE:
    def __init__(self):
        self.body = [Vector2(5,10), Vector2(4,10), Vector2(3,10)]
        self.direction = Vector2(0,0)
        self.new_block = False
        self.alive = True
        self.score = (len(self.body) - 3)
        #Images for snakes different positions.
        self.head_up = pygame.image.load('Graphics/head_up.png').convert_alpha()
        self.head_down = pygame.image.load('Graphics/head_down.png').convert_alpha()
        self.head_right = pygame.image.load('Graphics/head_right.png').convert_alpha()
        self.head_left = pygame.image.load('Graphics/head_left.png').convert_alpha()
        self.tail_up = pygame.image.load('Graphics/tail_up.png').convert_alpha()
        self.tail_down = pygame.image.load('Graphics/tail_down.png').convert_alpha()
        self.tail_right = pygame.image.load('Graphics/tail_right.png').convert_alpha()
        self.tail_left = pygame.image.load('Graphics/tail_left.png').convert_alpha()
        self.body_vertical = pygame.image.load('Graphics/body_vertical.png').convert_alpha()
        self.body_horizontal = pygame.image.load('Graphics/body_horizontal.png').convert_alpha()
        self.body_tr = pygame.image.load('Graphics/body_tr.png').convert_alpha()
        self.body_tl = pygame.image.load('Graphics/body_tl.png').convert_alpha()
        self.body_br = pygame.image.load('Graphics/body_br.png').convert_alpha()
        self.body_bl = pygame.image.load('Graphics/body_bl.png').convert_alpha()
        
    def draw_snake(self):
        self.update_head_graphics()
        self.update_tail_graphics()
        
        for index,block in enumerate(self.body):
            x_pos = int(block.x * cell_size)
            y_pos = int(block.y * cell_size)
            block_rect = pygame.Rect(x_pos,y_pos,cell_size,cell_size)
            
            if index == 0:
                screen.blit(self.head,block_rect)
            elif index == len(self.body) - 1:
                screen.blit(self.tail,block_rect)
            else:
                previous_block = self.body[index + 1] - block
                next_block= self.body[index - 1] - block
                if previous_block.x == next_block.x:
                    screen.blit(self.body_vertical,block_rect)
                elif previous_block.y == next_block.y:
                    screen.blit(self.body_horizontal,block_rect)
                else:
                    if previous_block.x == -1 and next_block.y == -1 or previous_block.y == -1 and next_block.x == -1:
                        screen.blit(self.body_tl,block_rect)
                    elif previous_block.x == -1 and next_block.y == 1 or previous_block.y == 1 and next_block.x == -1:
                        screen.blit(self.body_bl,block_rect)
                    elif previous_block.x == 1 and next_block.y == -1 or previous_block.y == -1 and next_block.x == 1:
                        screen.blit(self.body_tr,block_rect)
                    elif previous_block.x == 1 and next_block.y == 1 or previous_block.y == 1 and next_block.x == 1:
                        screen.blit(self.body_br,block_rect)

            
    def update_head_graphics(self):
        head_relation = self.body[1] - self.body[0] #New vector of past position vs current, gives direction
        if head_relation == Vector2(1,0):
            self.head = self.head_left
        elif head_relation == Vector2(-1,0):
            self.head = self.head_right
        elif head_relation == Vector2(0,1):
            self.head = self.head_up
        elif head_relation == Vector2(0,-1):
            self.head = self.head_down
            
    def update_tail_graphics(self):
        tail_relation = self.body[-2] - self.body[-1]
        if tail_relation == Vector2(1,0):
            self.tail = self.tail_left
        elif tail_relation == Vector2(-1,0):
            self.tail = self.tail_right
        elif tail_relation == Vector2(0,1):
            self.tail = self.tail_up
        elif tail_relation == Vector2(0,-1):
            self.tail = self.tail_down        
            
    def move_snake(self):
        if self.new_block == True:
            body_copy = self.body[:]
            body_copy.insert(0,body_copy[0] + self.direction)
            self.body = body_copy[:]
            self.new_block = False
        else:
            body_copy = self.body[:-1]
            body_copy.insert(0,body_copy[0] + self.direction)
            self.body = body_copy[:]
        
        
    def add_block(self):
        self.new_block = True

    def reset(self):
        self.score = (len(self.body) - 3)
        self.body = [Vector2(5,10), Vector2(4,10), Vector2(3,10)]
        self.direction = Vector2(0,0)
        
        
class DONUT:
    def __init__(self):
        self.randomize()
    
    def draw_donut(self):
        donut_rect = pygame.Rect(int(self.pos.x * cell_size), int(self.pos.y * cell_size), cell_size, cell_size)
        screen.blit(donut, donut_rect)
        
    def randomize(self):
        self.x = random.randint(0, cell_number -1)
        self.y = random.randint(0, cell_number -1)
        self.pos = Vector2(self.x,self.y)
        
class MAIN:
    def __init__(self):
        self.snake = SNAKE()
        self.donut = DONUT()
        
    def update(self):
        self.snake.move_snake()
        self.check_collision()
        self.check_fail()
        
    def draw_elements(self):
        self.draw_grass()
        self.donut.draw_donut()
        self.snake.draw_snake()
        self.draw_score()
        
    def check_collision(self):
        if self.donut.pos == self.snake.body[0]:
            self.donut.randomize()
            self.snake.add_block()
            
        for block in self.snake.body[1:]:
            if block == self.donut.pos:
                self.donut.randomize()
            
    def check_fail(self):
        #If snakes head is not in cell between 0 and cell_number -1
        if not 0 <= self.snake.body[0].x < cell_number or not 0 <= self.snake.body[0].y < cell_number:
            self.game_over()
            
        for block in self.snake.body[1:]:
            if block == self.snake.body[0]:
                self.game_over()
            
    def game_over(self):
        self.snake.alive = False
        self.snake.reset()
            
    def draw_grass(self):
        grass_color = (167,209,61)
        for row in range(cell_number):
            if row % 2 == 0:
                for col in range(cell_number):
                    if col % 2 == 0:
                        grass_rect = pygame.Rect(col * cell_size,row * cell_size,cell_size,cell_size)
                        pygame.draw.rect(screen, grass_color, grass_rect)
            else:
                for col in range(cell_number):
                    if col % 2 != 0:
                        grass_rect = pygame.Rect(col * cell_size,row * cell_size,cell_size,cell_size)
                        pygame.draw.rect(screen, grass_color, grass_rect)
                        
    def draw_score(self):
        score_text = str(len(self.snake.body) - 3)
        score_surface = game_font.render(score_text, True, (56,74,12))
        score_x = int(cell_size * cell_number - 60)
        score_y = int(cell_size * cell_number - 40)
        score_rect = score_surface.get_rect(center = (score_x, score_y))
        donut_rect = donut.get_rect(midright = (score_rect.left, score_rect.centery))
        
        screen.blit(score_surface, score_rect)    
        screen.blit(donut, donut_rect)
        
    def traverseObservation(self, x_steps, y_steps, x_head, y_head, intercardinal = False):
        x_head = x_head + 1
        y_head = y_head + 1
        steps = 1
        donut = -1
        body = -1
        boundary = -1

        x = x_head + x_steps
        y = y_head + y_steps
        max_x = cell_number
        max_y = cell_number

        while (x > -1) and (y > -1) and (x < max_x) and (y < max_y):
            if self.donut.pos.x == x and self.donut.pos.y == y:
                if donut == -1: 
                    if intercardinal == True:
                        donut = steps * 2
                    else:
                        donut = steps
                    #print("Observed donut at:", steps, "steps")
                    
            #if not 0 <= x < cell_number or not 0 <= y < cell_number:
            if x >= cell_number -1 or y >= cell_number -1 or x < 1 or y < 1:
                if boundary == -1:
                    if intercardinal == True:
                        boundary = steps * 2
                    else:
                        boundary = steps
                    #print("Observed boundary at:", steps, "steps")

            for block in self.snake.body[1:]:
                if block.x == x and block.y == y:
                    if body == -1:
                        if intercardinal == True:
                            body = steps * 2
                        else:
                            body = steps
                    #print("Observed body at:", steps, "steps")
                            
            steps += 1
            x += x_steps
            y += y_steps

        return [donut,boundary,body]
        
    def observe(self):
        x = int(self.snake.body[0].x)
        y = int(self.snake.body[0].y)

        observation = np.array([                
                    # up
                    self.traverseObservation(0, -1, x, y),
                    # up right
                    self.traverseObservation(1, -1, x, y, intercardinal=True),
                    # right
                    self.traverseObservation(1, 0, x, y),
                    # down right
                    self.traverseObservation(1, 1, x, y, intercardinal=True),
                    # down
                    self.traverseObservation(0, 1, x, y),
                    # down left
                    self.traverseObservation(-1, 1, x, y, intercardinal=True),
                    # left
                    self.traverseObservation(-1, 0, x, y),
                    # up left
                    self.traverseObservation(-1, -1, x, y, intercardinal=True),])

        return observation
        
    def think(self, observations):
        best_action = np.argmax(observations)
        if best_action == 0:
            return (0,-1)
        if best_action == 1:
            return (0, 1)
        if best_action == 2:
            return (1, 0)
        if best_action == 3:
            return (-1, 0)

# %% [markdown]
# # Neural Network functions
# The functions below are used to generate an initial population, calculate fitness with the min-max algorithm and also mutate the weights of the models for each generation.

# %%
#Softmax = Probabilistic argmax, returns probabilites that sum to 1.0, [0.2, 0.2, 0.4, 0.1] for our actions.
#Kernel_initializer is glorot_uniform by default for weights.
def generate_network():
    i = Input(shape=[8, 3])
    network = Dense(24)(i)
    network = Dense(24)(network)
    network = Dense(4, activation='softmax')(network)
    model = Model(i, network)
    return model

def compile_model(model):
    model.compile()
    return model

def fitness_function(donuts, maxscore, minscore = 0):
    return (donuts-minscore)/(maxscore-minscore)

def generate_population(population_size):
    population = []
    for n in range(population_size):
        model = generate_network()
        model = compile_model(model)
        population.append(model)
    return population

def mutate_organism(organism, my):
    weights = organism.get_weights()
    test_list = weights.copy()
    for i in range(len(weights)):
        for j in range(len(weights[i])):
            if weights[i][j].any() == 0.0:
                continue
            for x in range(len(weights[i][j])):
                if np.random.random()<my:
                    weights[i][j][x] += round(random.uniform(-1, 1), 8)
    offspring = generate_network()
    offspring.set_weights(weights)
    compile_model(offspring)     
    return offspring

# %%
x = [[1,2],[5,4]]
print(x)
x[1][1] = 0
print(x)
# Out:
# [[1, 2], [5, 4]]
# [[1, 2], [5, 0]]

# %%
# def mutate_organism(organism, my):
#     weights = organism.get_weights()
#     test_list = weights.copy()
#     for i in range(len(weights)):
#         inner_weights = weights[i]
#         for j in range(len(inner_weights)):
#             if inner_weights[j].any() == 0.0:
#                 continue
#             layer_weights = inner_weights[j]
#             for x in range(len(layer_weights)):
#                 layer_weights[x] += round(random.uniform(-1, 1), 8)
#             inner_weights[j] = layer_weights
#         weights[i] = inner_weights
#     organism.set_weights(weights) 
    
#     if weights == test_list:
#         print("Lists are the same")
#     else:
#         print("Lists are not the same")
#     return organism


# def mutate_organism(organism, my):
#     weights = organism.get_weights()
#     test_list = weights.copy()
#     for i in range(len(weights)):
#         for j in range(len(weights[i])):
#             if weights[i][j].any() == 0.0:
#                 continue
#             for x in range(len(weights[i][j])):
#                 if np.random.random()<my:
#                     weights[i][j][x] = round(random.uniform(-1, 1), 8)
#     organism.set_weights(weights) 
    
#     if weights == test_list:
#         print("Lists are the same")
#     else:
#         print("Lists are not the same")
#     return organism

# %% [markdown]
# ## Initializing population

# %%
population_size = 250
population = generate_population(population_size)

# %%
a, b  = population[0].layers[1].get_weights()
c, d  = population[0].layers[2].get_weights()
e, f  = population[0].layers[3].get_weights()
print("Input > Hidden:\n", a.shape, b.shape)
print("Hidden > Hidden:\n", c.shape, d.shape)
print("Input > Output:\n", e.shape, f.shape)
# Out:
# Input > Hidden:
#  (3, 24) (24,)
# Hidden > Hidden:
#  (24, 24) (24,)
# Input > Output:
#  (24, 4) (4,)

# %% [markdown]
# # Game / GA Loop

# %%
framerate = 60
ms_timer = 5
generations = 250
my=0.05
max_donuts = (cell_number * cell_number)-4
mean_fitness = []

pygame.init()
pygame.display.set_caption('Agent SNEK')
programIcon = pygame.image.load('graphics/donut40x40.png')
pygame.display.set_icon(programIcon)
screen = pygame.display.set_mode((cell_number * cell_size, cell_number * cell_size))
clock = pygame.time.Clock()
donut = pygame.image.load('graphics/donut40x40.png').convert_alpha()
game_font = pygame.font.Font(None, 35)

main_game = MAIN()

SCREEN_UPDATE = pygame.USEREVENT
pygame.time.set_timer(SCREEN_UPDATE, ms_timer)

while True:
    for generation in range(generations):
        my = 0.1 - (((generation+1)*0.0001)*3)
        print("Mutation Rate:",my)
        start_time = time.time()
        scores = []
        for organism in population:
            max_steps = (main_game.snake.score+1)*50
            steps = 0
            main_game.snake.alive = True
            main_game.donut.randomize()
            while main_game.snake.alive == True:
                for event in pygame.event.get():
                    if main_game.snake.alive == False:
                        break
                    if event.type == pygame.QUIT:
                        pygame.quit()
                        sys.exit()   
                    if event.type == SCREEN_UPDATE:
                        observations = main_game.observe()
                        action_potential = organism(observations.reshape(1,8,3))[0,0]
                        action = main_game.think(action_potential)
                        if action == (0,-1): #UP
                            if main_game.snake.direction.y != 1:
                                main_game.snake.direction = Vector2(action)
                        if action == (0, 1): #DOWN
                            if main_game.snake.direction.y != -1:
                                main_game.snake.direction = Vector2(action)
                        if action == (1, 0): #RIGHT
                            if main_game.snake.direction.x != -1:
                                main_game.snake.direction = Vector2(action)
                        if action == (-1, 0): #LEFT
                            if main_game.snake.direction.x != 1:
                                main_game.snake.direction = Vector2(action)
                        steps += 1
                        main_game.update()
                        if steps >= max_steps:
                            scores.append(fitness_function(main_game.snake.score, max_donuts))
                            main_game.snake.alive = False
                            main_game.snake.reset()
                            break
                        if main_game.snake.alive == False:
                            scores.append(fitness_function(main_game.snake.score, max_donuts))
                            break
                    screen.fill((175,215,70))
                    main_game.draw_elements()
                    pygame.display.update()
                    clock.tick(framerate)
    
    
        maxscore = max(scores)
        next_population = []
        for n in range(population_size):
            rand_organism = np.random.randint(population_size)
            if n<3:
                rand_organism = scores.index(maxscore)
            else:
                rand_organism_2 = np.random.randint(population_size)
                if scores[rand_organism_2]>scores[rand_organism]:
                    rand_organism=rand_organism_2
            next_population.append(mutate_organism(population[rand_organism], my))
        population = next_population
        end_time = time.time()
        mean_fitness.append(sum(scores)/len(scores))
        print("Generation:",generation+1, ", Max fitness:",maxscore,", Max donuts:",(maxscore*(cell_number*cell_number)),
              ", Average fitness:",sum(scores)/len(scores),
              ", Time passed(minutes):", round(end_time - start_time)/60)
    pygame.quit()
    sys.exit()
# Out:
# 0.09970000000000001
# Generation: 1 , Max fitness: 0.020833333333333332 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.43333333333333335
# 0.0994
# Generation: 2 , Max fitness: 0.010416666666666666 , Average fitness: 0.00020833333333333332 , Time passed(minutes): 0.45
# 0.09910000000000001
# Generation: 3 , Max fitness: 0.010416666666666666 , Average fitness: 0.00020833333333333332 , Time passed(minutes): 0.43333333333333335
# 0.0988
# Generation: 4 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.48333333333333334
# 0.0985
# Generation: 5 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.48333333333333334
# 0.09820000000000001
# Generation: 6 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.5
# 0.0979
# Generation: 7 , Max fitness: 0.020833333333333332 , Average fitness: 0.0003333333333333333 , Time passed(minutes): 0.48333333333333334
# 0.0976
# Generation: 8 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.45
# 0.09730000000000001
# Generation: 9 , Max fitness: 0.010416666666666666 , Average fitness: 0.00020833333333333332 , Time passed(minutes): 0.4666666666666667
# 0.097
# Generation: 10 , Max fitness: 0.020833333333333332 , Average fitness: 0.0005 , Time passed(minutes): 0.48333333333333334
# 0.09670000000000001
# Generation: 11 , Max fitness: 0.03125 , Average fitness: 0.000375 , Time passed(minutes): 0.5166666666666667
# 0.0964
# Generation: 12 , Max fitness: 0.010416666666666666 , Average fitness: 0.0004166666666666667 , Time passed(minutes): 0.5333333333333333
# 0.0961
# Generation: 13 , Max fitness: 0.010416666666666666 , Average fitness: 0.0004166666666666667 , Time passed(minutes): 0.5333333333333333
# 0.09580000000000001
# Generation: 14 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.55
# 0.0955
# Generation: 15 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.5166666666666667
# 0.0952
# Generation: 16 , Max fitness: 0.010416666666666666 , Average fitness: 0.00016666666666666666 , Time passed(minutes): 0.5166666666666667
# 0.09490000000000001
# Generation: 17 , Max fitness: 0.020833333333333332 , Average fitness: 0.00024999999999999995 , Time passed(minutes): 0.5666666666666667
# 0.0946
# Generation: 18 , Max fitness: 0.010416666666666666 , Average fitness: 0.0004166666666666667 , Time passed(minutes): 0.5333333333333333
# 0.09430000000000001
# Generation: 19 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.55
# 0.094
# Generation: 20 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.55
# 0.0937
# Generation: 21 , Max fitness: 0.010416666666666666 , Average fitness: 0.0003333333333333333 , Time passed(minutes): 0.5333333333333333
# 0.09340000000000001
# Generation: 22 , Max fitness: 0.020833333333333332 , Average fitness: 0.0010833333333333333 , Time passed(minutes): 0.55
# 0.0931
# Generation: 23 , Max fitness: 0.010416666666666666 , Average fitness: 0.000375 , Time passed(minutes): 0.5333333333333333
# 0.09280000000000001
# Generation: 24 , Max fitness: 0.020833333333333332 , Average fitness: 0.001083333333333333 , Time passed(minutes): 0.5666666666666667
# 0.0925
# Generation: 25 , Max fitness: 0.010416666666666666 , Average fitness: 0.0003333333333333333 , Time passed(minutes): 0.5166666666666667
# 0.0922
# Generation: 26 , Max fitness: 0.010416666666666666 , Average fitness: 0.00029166666666666664 , Time passed(minutes): 0.5166666666666667
# 0.09190000000000001
# Generation: 27 , Max fitness: 0.010416666666666666 , Average fitness: 0.0007499999999999998 , Time passed(minutes): 0.5666666666666667
# 0.0916
# Generation: 28 , Max fitness: 0.020833333333333332 , Average fitness: 0.00045833333333333327 , Time passed(minutes): 0.6333333333333333
# 0.0913
# Generation: 29 , Max fitness: 0.020833333333333332 , Average fitness: 0.0008333333333333332 , Time passed(minutes): 0.7333333333333333
# 0.091
# Generation: 30 , Max fitness: 0.020833333333333332 , Average fitness: 0.0007916666666666664 , Time passed(minutes): 0.7
# 0.0907
# Generation: 31 , Max fitness: 0.020833333333333332 , Average fitness: 0.0008749999999999998 , Time passed(minutes): 0.6833333333333333
# 0.09040000000000001
# Generation: 32 , Max fitness: 0.010416666666666666 , Average fitness: 0.0006666666666666665 , Time passed(minutes): 0.6833333333333333
# 0.09010000000000001
# Generation: 33 , Max fitness: 0.010416666666666666 , Average fitness: 0.0007499999999999998 , Time passed(minutes): 0.7
# 0.0898
# Generation: 34 , Max fitness: 0.020833333333333332 , Average fitness: 0.0008749999999999998 , Time passed(minutes): 0.7166666666666667
# 0.08950000000000001
# Generation: 35 , Max fitness: 0.020833333333333332 , Average fitness: 0.0005833333333333333 , Time passed(minutes): 0.85
# 0.0892
# Generation: 36 , Max fitness: 0.020833333333333332 , Average fitness: 0.0009166666666666664 , Time passed(minutes): 0.8666666666666667
# 0.0889
# Generation: 37 , Max fitness: 0.020833333333333332 , Average fitness: 0.001083333333333333 , Time passed(minutes): 0.85
# 0.08860000000000001
# Generation: 38 , Max fitness: 0.020833333333333332 , Average fitness: 0.001583333333333334 , Time passed(minutes): 0.8833333333333333
# 0.0883
# Generation: 39 , Max fitness: 0.020833333333333332 , Average fitness: 0.0013750000000000001 , Time passed(minutes): 0.8666666666666667
# 0.08800000000000001
# Generation: 40 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012916666666666669 , Time passed(minutes): 0.8833333333333333
# 0.0877
# Generation: 41 , Max fitness: 0.010416666666666666 , Average fitness: 0.0011249999999999997 , Time passed(minutes): 0.9
# 0.0874
# Generation: 42 , Max fitness: 0.020833333333333332 , Average fitness: 0.0011666666666666665 , Time passed(minutes): 0.9666666666666667
# 0.08710000000000001
# Generation: 43 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012916666666666664 , Time passed(minutes): 0.8666666666666667
# 0.0868
# Generation: 44 , Max fitness: 0.020833333333333332 , Average fitness: 0.0011666666666666665 , Time passed(minutes): 0.85
# 0.08650000000000001
# Generation: 45 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012499999999999998 , Time passed(minutes): 0.85
# 0.0862
# Generation: 46 , Max fitness: 0.03125 , Average fitness: 0.001375 , Time passed(minutes): 0.8666666666666667
# 0.0859
# Generation: 47 , Max fitness: 0.020833333333333332 , Average fitness: 0.0011249999999999997 , Time passed(minutes): 0.85
# 0.08560000000000001
# Generation: 48 , Max fitness: 0.020833333333333332 , Average fitness: 0.001125 , Time passed(minutes): 0.8666666666666667
# 0.0853
# Generation: 49 , Max fitness: 0.010416666666666666 , Average fitness: 0.0008749999999999997 , Time passed(minutes): 0.85
# 0.085
# Generation: 50 , Max fitness: 0.020833333333333332 , Average fitness: 0.0013333333333333333 , Time passed(minutes): 0.85
# 0.0847
# Generation: 51 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012500000000000002 , Time passed(minutes): 0.9333333333333333
# 0.0844
# Generation: 52 , Max fitness: 0.020833333333333332 , Average fitness: 0.0007916666666666664 , Time passed(minutes): 0.8833333333333333
# 0.08410000000000001
# Generation: 53 , Max fitness: 0.020833333333333332 , Average fitness: 0.0014583333333333336 , Time passed(minutes): 0.8666666666666667
# 0.08380000000000001
# Generation: 54 , Max fitness: 0.03125 , Average fitness: 0.0017083333333333338 , Time passed(minutes): 0.9
# 0.0835
# Generation: 55 , Max fitness: 0.020833333333333332 , Average fitness: 0.001375 , Time passed(minutes): 0.8833333333333333
# 0.08320000000000001
# Generation: 56 , Max fitness: 0.03125 , Average fitness: 0.0013750000000000004 , Time passed(minutes): 0.9166666666666666
# 0.0829
# Generation: 57 , Max fitness: 0.020833333333333332 , Average fitness: 0.0016250000000000006 , Time passed(minutes): 0.9333333333333333
# 0.0826
# Generation: 58 , Max fitness: 0.010416666666666666 , Average fitness: 0.0010416666666666662 , Time passed(minutes): 0.8833333333333333
# 0.08230000000000001
# Generation: 59 , Max fitness: 0.020833333333333332 , Average fitness: 0.00125 , Time passed(minutes): 0.8833333333333333
# 0.082
# Generation: 60 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012916666666666664 , Time passed(minutes): 0.8833333333333333
# 0.08170000000000001
# Generation: 61 , Max fitness: 0.010416666666666666 , Average fitness: 0.0011666666666666665 , Time passed(minutes): 0.9833333333333333
# 0.0814
# Generation: 62 , Max fitness: 0.03125 , Average fitness: 0.0015416666666666667 , Time passed(minutes): 0.85
# 0.0811
# Generation: 63 , Max fitness: 0.020833333333333332 , Average fitness: 0.0013333333333333333 , Time passed(minutes): 0.8833333333333333
# 0.08080000000000001
# Generation: 64 , Max fitness: 0.020833333333333332 , Average fitness: 0.0014583333333333336 , Time passed(minutes): 0.8666666666666667
# 0.0805
# Generation: 65 , Max fitness: 0.020833333333333332 , Average fitness: 0.00125 , Time passed(minutes): 0.8333333333333334
# 0.08020000000000001
# Generation: 66 , Max fitness: 0.020833333333333332 , Average fitness: 0.0014583333333333338 , Time passed(minutes): 0.85
# 0.0799
# Generation: 67 , Max fitness: 0.03125 , Average fitness: 0.0015833333333333342 , Time passed(minutes): 0.8666666666666667
# 0.0796
# Generation: 68 , Max fitness: 0.020833333333333332 , Average fitness: 0.0016250000000000004 , Time passed(minutes): 0.8333333333333334
# 0.07930000000000001
# Generation: 69 , Max fitness: 0.020833333333333332 , Average fitness: 0.001083333333333333 , Time passed(minutes): 0.8833333333333333
# 0.079
# Generation: 70 , Max fitness: 0.010416666666666666 , Average fitness: 0.00125 , Time passed(minutes): 0.8833333333333333
# 0.0787
# Generation: 71 , Max fitness: 0.020833333333333332 , Average fitness: 0.0014166666666666668 , Time passed(minutes): 0.8833333333333333
# 0.0784
# Generation: 72 , Max fitness: 0.020833333333333332 , Average fitness: 0.00125 , Time passed(minutes): 1.0333333333333334
# 0.0781
# Generation: 73 , Max fitness: 0.020833333333333332 , Average fitness: 0.0016250000000000001 , Time passed(minutes): 0.9
# 0.07780000000000001
# Generation: 74 , Max fitness: 0.020833333333333332 , Average fitness: 0.001083333333333333 , Time passed(minutes): 0.9333333333333333
# 0.0775
# Generation: 75 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012916666666666667 , Time passed(minutes): 0.9166666666666666
# 0.0772
# Generation: 76 , Max fitness: 0.020833333333333332 , Average fitness: 0.0015000000000000002 , Time passed(minutes): 0.8833333333333333
# 0.0769
# Generation: 77 , Max fitness: 0.020833333333333332 , Average fitness: 0.001083333333333333 , Time passed(minutes): 0.8666666666666667
# 0.0766
# Generation: 78 , Max fitness: 0.010416666666666666 , Average fitness: 0.001083333333333333 , Time passed(minutes): 0.8833333333333333
# 0.0763
# Generation: 79 , Max fitness: 0.03125 , Average fitness: 0.0012916666666666669 , Time passed(minutes): 0.8833333333333333
# 0.07600000000000001
# Generation: 80 , Max fitness: 0.020833333333333332 , Average fitness: 0.0011666666666666665 , Time passed(minutes): 0.8833333333333333
# 0.0757
# Generation: 81 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012916666666666667 , Time passed(minutes): 0.8833333333333333
# 0.0754
# Generation: 82 , Max fitness: 0.020833333333333332 , Average fitness: 0.0011249999999999995 , Time passed(minutes): 0.8666666666666667
# 0.0751
# Generation: 83 , Max fitness: 0.020833333333333332 , Average fitness: 0.0014166666666666668 , Time passed(minutes): 0.85
# 0.0748
# Generation: 84 , Max fitness: 0.010416666666666666 , Average fitness: 0.0011249999999999997 , Time passed(minutes): 0.8666666666666667
# 0.07450000000000001
# Generation: 85 , Max fitness: 0.020833333333333332 , Average fitness: 0.0017916666666666673 , Time passed(minutes): 0.9
# 0.0742
# Generation: 86 , Max fitness: 0.020833333333333332 , Average fitness: 0.0017500000000000007 , Time passed(minutes): 0.9166666666666666
# 0.0739
# Generation: 87 , Max fitness: 0.020833333333333332 , Average fitness: 0.0014583333333333338 , Time passed(minutes): 1.0666666666666667
# 0.0736
# Generation: 88 , Max fitness: 0.020833333333333332 , Average fitness: 0.0014583333333333336 , Time passed(minutes): 0.9333333333333333
# 0.0733
# Generation: 89 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012500000000000002 , Time passed(minutes): 0.9166666666666666
# 0.07300000000000001
# Generation: 90 , Max fitness: 0.020833333333333332 , Average fitness: 0.0014166666666666668 , Time passed(minutes): 0.9333333333333333
# 0.0727
# Generation: 91 , Max fitness: 0.010416666666666666 , Average fitness: 0.001416666666666667 , Time passed(minutes): 0.9833333333333333
# 0.0724
# Generation: 92 , Max fitness: 0.020833333333333332 , Average fitness: 0.0017083333333333343 , Time passed(minutes): 1.0333333333333334
# 0.0721
# Generation: 93 , Max fitness: 0.020833333333333332 , Average fitness: 0.0018750000000000006 , Time passed(minutes): 1.0166666666666666
# 0.0718
# Generation: 94 , Max fitness: 0.020833333333333332 , Average fitness: 0.002208333333333334 , Time passed(minutes): 0.9833333333333333
# 0.07150000000000001
# Generation: 95 , Max fitness: 0.020833333333333332 , Average fitness: 0.0020833333333333337 , Time passed(minutes): 1.0166666666666666
# 0.0712
# Generation: 96 , Max fitness: 0.020833333333333332 , Average fitness: 0.0017916666666666675 , Time passed(minutes): 1.0666666666666667
# 0.0709
# Generation: 97 , Max fitness: 0.03125 , Average fitness: 0.0016250000000000006 , Time passed(minutes): 1.05
# 0.07060000000000001
# Generation: 98 , Max fitness: 0.020833333333333332 , Average fitness: 0.002000000000000001 , Time passed(minutes): 1.0666666666666667
# 0.0703
# Generation: 99 , Max fitness: 0.041666666666666664 , Average fitness: 0.0020416666666666673 , Time passed(minutes): 1.0333333333333334
# 0.07
# Generation: 100 , Max fitness: 0.020833333333333332 , Average fitness: 0.001666666666666667 , Time passed(minutes): 1.0
# 0.0697
# Generation: 101 , Max fitness: 0.020833333333333332 , Average fitness: 0.0021250000000000006 , Time passed(minutes): 1.0166666666666666
# 0.0694
# Generation: 102 , Max fitness: 0.020833333333333332 , Average fitness: 0.002000000000000001 , Time passed(minutes): 1.0333333333333334
# 0.06910000000000001
# Generation: 103 , Max fitness: 0.020833333333333332 , Average fitness: 0.0016666666666666672 , Time passed(minutes): 1.3833333333333333
# 0.0688
# Generation: 104 , Max fitness: 0.020833333333333332 , Average fitness: 0.002458333333333334 , Time passed(minutes): 1.05
# 0.0685
# Generation: 105 , Max fitness: 0.020833333333333332 , Average fitness: 0.0018333333333333346 , Time passed(minutes): 1.0333333333333334
# 0.06820000000000001
# Generation: 106 , Max fitness: 0.020833333333333332 , Average fitness: 0.0018333333333333342 , Time passed(minutes): 1.05
# 0.0679
# Generation: 107 , Max fitness: 0.020833333333333332 , Average fitness: 0.0012916666666666669 , Time passed(minutes): 1.0166666666666666
# 0.06760000000000001
# Generation: 108 , Max fitness: 0.020833333333333332 , Average fitness: 0.0018750000000000008 , Time passed(minutes): 1.0
# 0.0673
# Generation: 109 , Max fitness: 0.041666666666666664 , Average fitness: 0.00225 , Time passed(minutes): 1.0333333333333334
# 0.067
# Generation: 110 , Max fitness: 0.020833333333333332 , Average fitness: 0.00225 , Time passed(minutes): 1.0166666666666666
# 0.06670000000000001
# Generation: 111 , Max fitness: 0.020833333333333332 , Average fitness: 0.002000000000000001 , Time passed(minutes): 1.0166666666666666
# 0.06640000000000001
# Generation: 112 , Max fitness: 0.020833333333333332 , Average fitness: 0.0019583333333333345 , Time passed(minutes): 1.0166666666666666
# 0.0661
# Generation: 113 , Max fitness: 0.020833333333333332 , Average fitness: 0.0020833333333333333 , Time passed(minutes): 1.0166666666666666
# 0.0658
# Generation: 114 , Max fitness: 0.020833333333333332 , Average fitness: 0.0017500000000000007 , Time passed(minutes): 1.0
# 0.0655
# Generation: 115 , Max fitness: 0.020833333333333332 , Average fitness: 0.0023749999999999995 , Time passed(minutes): 1.0
# 0.06520000000000001
# Generation: 116 , Max fitness: 0.020833333333333332 , Average fitness: 0.0019166666666666676 , Time passed(minutes): 1.0166666666666666
# 0.06490000000000001
# Generation: 117 , Max fitness: 0.020833333333333332 , Average fitness: 0.0022916666666666675 , Time passed(minutes): 1.0333333333333334
# 0.0646
# Generation: 118 , Max fitness: 0.03125 , Average fitness: 0.002083333333333334 , Time passed(minutes): 1.0166666666666666
# 0.0643
# Generation: 119 , Max fitness: 0.020833333333333332 , Average fitness: 0.001875000000000001 , Time passed(minutes): 1.0333333333333334
# 0.064
# Generation: 120 , Max fitness: 0.020833333333333332 , Average fitness: 0.001708333333333334 , Time passed(minutes): 1.0333333333333334
# 0.0637
# Generation: 121 , Max fitness: 0.020833333333333332 , Average fitness: 0.0016666666666666674 , Time passed(minutes): 1.0166666666666666
# 0.06340000000000001
# Generation: 122 , Max fitness: 0.020833333333333332 , Average fitness: 0.0018750000000000006 , Time passed(minutes): 1.0333333333333334
# 0.0631
# Generation: 123 , Max fitness: 0.020833333333333332 , Average fitness: 0.0017500000000000003 , Time passed(minutes): 1.2333333333333334
# 0.0628
# Generation: 124 , Max fitness: 0.020833333333333332 , Average fitness: 0.0019166666666666676 , Time passed(minutes): 1.0166666666666666
# 0.0625
# Generation: 125 , Max fitness: 0.03125 , Average fitness: 0.002166666666666667 , Time passed(minutes): 1.0
# 0.062200000000000005
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8df4ba722a5d> in <module>
#      66                     main_game.draw_elements()
#      67                     pygame.display.update()
# ---> 68                     clock.tick(framerate)
#      69
#      70
#
# KeyboardInterrupt:

# %%
i = 1
for model in population:
    filename = '250_population/'+str(i)+'_organism_of_250.h5'
    model.save(filename)
    i+=1

# %% [markdown]
# OBSERVATION:
# Up = (0,-1)<br>
# Up-left = (-1,-1)<br>
# Up-right = (1,-1)<br>
# Right = (1,0)<br>
# Left = (-1,0)<br>
# Down = (0,1)<br>
# Down-left = (-1, 1)<br>
# Down-right = (1,1)<br><br>
