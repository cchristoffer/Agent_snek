# %% [markdown]
# # Solving Snake with Genetic Algorithm

# %%
#Graphics from https://opengameart.org/content/snake-game-assets

#1 FIX MUTATION!
#2 Lean back and have a beer

# %% [markdown]
# # Agent Snek observing environment
# <img src="observemodel.png" style="width: 75%">

# %% [markdown]
# # From Observation to  Action
# <img src="think_to_action.png">

# %% [markdown]
# # Flowchart of the Genetic Algorithm
# <img src="algo.png" style="width: 80%">

# %% [markdown]
# # Imports

# %%
import pygame
import sys
import random
from pygame.math import Vector2
import numpy as np
import math
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
import time
# Out:
# pygame 2.0.0.dev6 (SDL 2.0.10, python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # The game
# The three below classes keep track of everthing related to the game, it's components, states, positions and scores.
# ## Snake Class
# Instantiates with body, which is a list of 2d-Vectors with positions. Also keeps track if Snake is alive, adds another 2d-vector to the body list upon collision with a Donut, draws different PNG:s depending on direction of Snake and moves the snake upon taking action.
# ## Donut Class
# Holds positional recordings of current Donut, draws it and randomizes a new donut upon collision with Snake.
# ## Main Class
# Draws and updates the game, also holds track of scores, collisions, gamestates and the observing/thinking for the Snake object. Initiates with a Snake and Donut object.

# %%
cell_size = 40
cell_number = 10


class SNAKE:
    def __init__(self):
        self.body = [Vector2(2,5), Vector2(1,5), Vector2(0,5)]
        self.direction = Vector2(0,0)
        self.new_block = False
        self.alive = True
        self.score = (len(self.body) - 3)
        #Images for snakes different positions.
        self.head_up = pygame.image.load('Graphics/head_up.png').convert_alpha()
        self.head_down = pygame.image.load('Graphics/head_down.png').convert_alpha()
        self.head_right = pygame.image.load('Graphics/head_right.png').convert_alpha()
        self.head_left = pygame.image.load('Graphics/head_left.png').convert_alpha()
        self.tail_up = pygame.image.load('Graphics/tail_up.png').convert_alpha()
        self.tail_down = pygame.image.load('Graphics/tail_down.png').convert_alpha()
        self.tail_right = pygame.image.load('Graphics/tail_right.png').convert_alpha()
        self.tail_left = pygame.image.load('Graphics/tail_left.png').convert_alpha()
        self.body_vertical = pygame.image.load('Graphics/body_vertical.png').convert_alpha()
        self.body_horizontal = pygame.image.load('Graphics/body_horizontal.png').convert_alpha()
        self.body_tr = pygame.image.load('Graphics/body_tr.png').convert_alpha()
        self.body_tl = pygame.image.load('Graphics/body_tl.png').convert_alpha()
        self.body_br = pygame.image.load('Graphics/body_br.png').convert_alpha()
        self.body_bl = pygame.image.load('Graphics/body_bl.png').convert_alpha()
        
    def draw_snake(self):
        self.update_head_graphics()
        self.update_tail_graphics()
        
        for index,block in enumerate(self.body):
            x_pos = int(block.x * cell_size)
            y_pos = int(block.y * cell_size)
            block_rect = pygame.Rect(x_pos,y_pos,cell_size,cell_size)
            
            if index == 0:
                screen.blit(self.head,block_rect)
            elif index == len(self.body) - 1:
                screen.blit(self.tail,block_rect)
            else:
                previous_block = self.body[index + 1] - block
                next_block= self.body[index - 1] - block
                if previous_block.x == next_block.x:
                    screen.blit(self.body_vertical,block_rect)
                elif previous_block.y == next_block.y:
                    screen.blit(self.body_horizontal,block_rect)
                else:
                    if previous_block.x == -1 and next_block.y == -1 or previous_block.y == -1 and next_block.x == -1:
                        screen.blit(self.body_tl,block_rect)
                    elif previous_block.x == -1 and next_block.y == 1 or previous_block.y == 1 and next_block.x == -1:
                        screen.blit(self.body_bl,block_rect)
                    elif previous_block.x == 1 and next_block.y == -1 or previous_block.y == -1 and next_block.x == 1:
                        screen.blit(self.body_tr,block_rect)
                    elif previous_block.x == 1 and next_block.y == 1 or previous_block.y == 1 and next_block.x == 1:
                        screen.blit(self.body_br,block_rect)

            
    def update_head_graphics(self):
        head_relation = self.body[1] - self.body[0] #New vector of past position vs current, gives direction
        if head_relation == Vector2(1,0):
            self.head = self.head_left
        elif head_relation == Vector2(-1,0):
            self.head = self.head_right
        elif head_relation == Vector2(0,1):
            self.head = self.head_up
        elif head_relation == Vector2(0,-1):
            self.head = self.head_down
            
    def update_tail_graphics(self):
        tail_relation = self.body[-2] - self.body[-1]
        if tail_relation == Vector2(1,0):
            self.tail = self.tail_left
        elif tail_relation == Vector2(-1,0):
            self.tail = self.tail_right
        elif tail_relation == Vector2(0,1):
            self.tail = self.tail_up
        elif tail_relation == Vector2(0,-1):
            self.tail = self.tail_down        
            
    def move_snake(self):
        if self.new_block == True:
            body_copy = self.body[:]
            body_copy.insert(0,body_copy[0] + self.direction)
            self.body = body_copy[:]
            self.new_block = False
        else:
            body_copy = self.body[:-1]
            body_copy.insert(0,body_copy[0] + self.direction)
            self.body = body_copy[:]
        
        
    def add_block(self):
        self.new_block = True

    def reset(self):
        self.score = (len(self.body) - 3)
        self.body = [Vector2(2,5), Vector2(1,5), Vector2(0,5)]
        self.direction = Vector2(0,0)
        
        
class DONUT:
    def __init__(self):
        self.randomize()
    
    def draw_donut(self):
        donut_rect = pygame.Rect(int(self.pos.x * cell_size), int(self.pos.y * cell_size), cell_size, cell_size)
        screen.blit(donut, donut_rect)
        
    def randomize(self):
        self.x = random.randint(0, cell_number -1)
        self.y = random.randint(0, cell_number -1)
        self.pos = Vector2(self.x,self.y)
        
class MAIN:
    def __init__(self):
        self.snake = SNAKE()
        self.donut = DONUT()
        
    def update(self):
        self.snake.move_snake()
        self.check_collision()
        self.check_fail()
        
    def draw_elements(self):
        self.draw_grass()
        self.donut.draw_donut()
        self.snake.draw_snake()
        self.draw_score()
        
    def check_collision(self):
        if self.donut.pos == self.snake.body[0]:
            self.donut.randomize()
            self.snake.add_block()
            
        for block in self.snake.body[1:]:
            if block == self.donut.pos:
                self.donut.randomize()
            
    def check_fail(self):
        #If snakes head is not in cell between 0 and cell_number -1
        if not 0 <= self.snake.body[0].x < cell_number or not 0 <= self.snake.body[0].y < cell_number:
            self.game_over()
            
        for block in self.snake.body[1:]:
            if block == self.snake.body[0]:
                self.game_over()
            
    def game_over(self):
        self.snake.alive = False
        self.snake.reset()
            
    def draw_grass(self):
        grass_color = (167,209,61)
        for row in range(cell_number):
            if row % 2 == 0:
                for col in range(cell_number):
                    if col % 2 == 0:
                        grass_rect = pygame.Rect(col * cell_size,row * cell_size,cell_size,cell_size)
                        pygame.draw.rect(screen, grass_color, grass_rect)
            else:
                for col in range(cell_number):
                    if col % 2 != 0:
                        grass_rect = pygame.Rect(col * cell_size,row * cell_size,cell_size,cell_size)
                        pygame.draw.rect(screen, grass_color, grass_rect)
                        
    def draw_score(self):
        score_text = str(len(self.snake.body) - 3)
        score_surface = game_font.render(score_text, True, (56,74,12))
        score_x = int(cell_size * cell_number - 60)
        score_y = int(cell_size * cell_number - 40)
        score_rect = score_surface.get_rect(center = (score_x, score_y))
        donut_rect = donut.get_rect(midright = (score_rect.left, score_rect.centery))
        
        screen.blit(score_surface, score_rect)    
        screen.blit(donut, donut_rect)
        
    def traverseObservation(self, x_steps, y_steps, x_head, y_head, intercardinal = False):
        x_head = x_head + 1
        y_head = y_head + 1
        steps = 1
        donut = -1
        body = -1
        boundary = -1

        x = x_head + x_steps
        y = y_head + y_steps
        max_x = cell_number
        max_y = cell_number

        while (x > -1) and (y > -1) and (x < max_x) and (y < max_y):
            if self.donut.pos.x == x and self.donut.pos.y == y:
                if donut == -1: 
                    if intercardinal == True:
                        donut = steps * 2
                    else:
                        donut = steps
                    #print("Observed donut at:", steps, "steps")
                    
            #if not 0 <= x < cell_number or not 0 <= y < cell_number:
            if x >= cell_number -1 or y >= cell_number -1 or x < 1 or y < 1:
                if boundary == -1:
                    if intercardinal == True:
                        boundary = steps * 2
                    else:
                        boundary = steps
                    #print("Observed boundary at:", steps, "steps")

            for block in self.snake.body[1:]:
                if block.x == x and block.y == y:
                    if body == -1:
                        if intercardinal == True:
                            body = steps * 2
                        else:
                            body = steps
                    #print("Observed body at:", steps, "steps")
                            
            steps += 1
            x += x_steps
            y += y_steps

        return [donut,boundary,body]
        
    def observe(self):
        x = int(self.snake.body[0].x)
        y = int(self.snake.body[0].y)

        observation = np.array([                
                    # up
                    self.traverseObservation(0, -1, x, y),
                    # up right
                    self.traverseObservation(1, -1, x, y, intercardinal=True),
                    # right
                    self.traverseObservation(1, 0, x, y),
                    # down right
                    self.traverseObservation(1, 1, x, y, intercardinal=True),
                    # down
                    self.traverseObservation(0, 1, x, y),
                    # down left
                    self.traverseObservation(-1, 1, x, y, intercardinal=True),
                    # left
                    self.traverseObservation(-1, 0, x, y),
                    # up left
                    self.traverseObservation(-1, -1, x, y, intercardinal=True),])

        return observation
        
    def think(self, observations):
        best_action = np.argmax(observations)
        if best_action == 0:
            return (0,-1)
        if best_action == 1:
            return (0, 1)
        if best_action == 2:
            return (1, 0)
        if best_action == 3:
            return (-1, 0)

# %% [markdown]
# # Neural Network functions
# The functions below are used to generate an initial population, calculate fitness with the min-max algorithm and also mutate the weights of the models for each generation.

# %%
#Softmax = Probabilistic argmax, returns probabilites that sum to 1.0, [0.2, 0.2, 0.4, 0.1] for our actions.
#Kernel_initializer is glorot_uniform by default for weights.
def generate_network():
    i = Input(shape=[8, 3])
    network = Dense(24)(i)
    network = Dense(24)(network)
    network = Dense(4, activation='softmax')(network)
    model = Model(i, network)
    return model

def compile_model(model):
    model.compile()
    return model

def fitness_function(donuts, maxscore, minscore = 0):
    return (donuts-minscore)/(maxscore-minscore)

def generate_population(population_size):
    population = []
    for n in range(population_size):
        model = generate_network()
        model = compile_model(model)
        population.append(model)
    return population

def mutate_organism(organism, my):
    weights = organism.get_weights()
    test_list = weights.copy()
    for i in range(len(weights)):
        for j in range(len(weights[i])):
            if weights[i][j].any() == 0.0:
                continue
            for x in range(len(weights[i][j])):
                if np.random.random()<my:
                    weights[i][j][x] += round(random.uniform(-1, 1), 8)
    offspring = generate_network()
    offspring.set_weights(weights)
    compile_model(offspring)     
    return offspring

# %% [markdown]
# ## Initializing population

# %%
population_size = 100
population = generate_population(population_size)

# %%
a, b  = population[0].layers[1].get_weights()
c, d  = population[0].layers[2].get_weights()
e, f  = population[0].layers[3].get_weights()
print("Input > Hidden:\n", a.shape, b.shape)
print("Hidden > Hidden:\n", c.shape, d.shape)
print("Input > Output:\n", e.shape, f.shape)
# Out:
# Input > Hidden:
#  (3, 24) (24,)
# Hidden > Hidden:
#  (24, 24) (24,)
# Input > Output:
#  (24, 4) (4,)

# %% [markdown]
# # Game / GA Loop

# %%
framerate = 60
ms_timer = 10
generations = 2500
#my=0.1
max_donuts = (cell_number * cell_number)-4
mean_fitness = []

pygame.init()
pygame.display.set_caption('Agent SNEK')
programIcon = pygame.image.load('graphics/donut40x40.png')
pygame.display.set_icon(programIcon)
screen = pygame.display.set_mode((cell_number * cell_size, cell_number * cell_size))
clock = pygame.time.Clock()
donut = pygame.image.load('graphics/donut40x40.png').convert_alpha()
game_font = pygame.font.Font(None, 35)

main_game = MAIN()

SCREEN_UPDATE = pygame.USEREVENT
pygame.time.set_timer(SCREEN_UPDATE, ms_timer)

while True:
    for generation in range(generations):
        my = 0.1 - (((generation+1)*0.00005)*1.8)
        start_time = time.time()
        scores = []
        for organism in population:
            max_steps = (main_game.snake.score+1)*50
            steps = 0
            main_game.snake.alive = True
            main_game.donut.randomize()
            while main_game.snake.alive == True:
                for event in pygame.event.get():
                    if main_game.snake.alive == False:
                        break
                    if event.type == pygame.QUIT:
                        pygame.quit()
                        sys.exit()   
                    if event.type == SCREEN_UPDATE:
                        observations = main_game.observe()
                        action_potential = organism(observations.reshape(1,8,3))[0,0]
                        action = main_game.think(action_potential)
                        if action == (0,-1): #UP
                            if main_game.snake.direction.y != 1:
                                main_game.snake.direction = Vector2(action)
                        if action == (0, 1): #DOWN
                            if main_game.snake.direction.y != -1:
                                main_game.snake.direction = Vector2(action)
                        if action == (1, 0): #RIGHT
                            if main_game.snake.direction.x != -1:
                                main_game.snake.direction = Vector2(action)
                        if action == (-1, 0): #LEFT
                            if main_game.snake.direction.x != 1:
                                main_game.snake.direction = Vector2(action)
                        steps += 1
                        main_game.update()
                        if steps >= max_steps:
                            scores.append(fitness_function(main_game.snake.score, max_donuts))
                            main_game.snake.alive = False
                            main_game.snake.reset()
                            break
                        if main_game.snake.alive == False:
                            scores.append(fitness_function(main_game.snake.score, max_donuts))
                            break
                    screen.fill((175,215,70))
                    main_game.draw_elements()
                    pygame.display.update()
                    clock.tick(framerate)
    
    
        maxscore = max(scores)
        next_population = []
        for n in range(population_size):
            rand_organism = np.random.randint(population_size)
            if n<3:
                rand_organism = scores.index(maxscore)
            else:
                rand_organism_2 = np.random.randint(population_size)
                if scores[rand_organism_2]>scores[rand_organism]:
                    rand_organism=rand_organism_2
            next_population.append(mutate_organism(population[rand_organism], my))
        population = next_population
        end_time = time.time()
        mean_fitness.append(sum(scores)/len(scores))
        print("Generation:",generation+1, ", Max fitness:",maxscore,", Max donuts:",round(maxscore*(cell_number*cell_number)),
              ", Average fitness:",sum(scores)/len(scores),
              ", Time passed(minutes):", round(end_time - start_time)/60)
    pygame.quit()
    sys.exit()
# Out:
# Generation: 1 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.26666666666666666
# Generation: 2 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0003125 , Time passed(minutes): 0.25
# Generation: 3 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.00020833333333333332 , Time passed(minutes): 0.23333333333333334
# Generation: 4 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0007291666666666666 , Time passed(minutes): 0.23333333333333334
# Generation: 5 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0008333333333333333 , Time passed(minutes): 0.2833333333333333
# Generation: 6 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0005208333333333333 , Time passed(minutes): 0.26666666666666666
# Generation: 7 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.00020833333333333332 , Time passed(minutes): 0.26666666666666666
# Generation: 8 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.000625 , Time passed(minutes): 0.25
# Generation: 9 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.26666666666666666
# Generation: 10 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0007291666666666666 , Time passed(minutes): 0.26666666666666666
# Generation: 11 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.26666666666666666
# Generation: 12 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0007291666666666666 , Time passed(minutes): 0.26666666666666666
# Generation: 13 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.00041666666666666664 , Time passed(minutes): 0.26666666666666666
# Generation: 14 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.25
# Generation: 15 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.25
# Generation: 16 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.2833333333333333
# Generation: 17 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.31666666666666665
# Generation: 18 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.31666666666666665
# Generation: 19 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.3
# Generation: 20 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.00125 , Time passed(minutes): 0.31666666666666665
# Generation: 21 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0005208333333333333 , Time passed(minutes): 0.31666666666666665
# Generation: 22 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.3
# Generation: 23 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0007291666666666666 , Time passed(minutes): 0.3333333333333333
# Generation: 24 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0011458333333333336 , Time passed(minutes): 0.31666666666666665
# Generation: 25 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.3
# Generation: 26 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0005208333333333333 , Time passed(minutes): 0.3333333333333333
# Generation: 27 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0007291666666666666 , Time passed(minutes): 0.3
# Generation: 28 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0005208333333333333 , Time passed(minutes): 0.3
# Generation: 29 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.3
# Generation: 30 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.31666666666666665
# Generation: 31 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.3333333333333333
# Generation: 32 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.35
# Generation: 33 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0007291666666666666 , Time passed(minutes): 0.3333333333333333
# Generation: 34 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0008333333333333333 , Time passed(minutes): 0.31666666666666665
# Generation: 35 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0014583333333333332 , Time passed(minutes): 0.3333333333333333
# Generation: 36 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.3
# Generation: 37 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.3333333333333333
# Generation: 38 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0007291666666666666 , Time passed(minutes): 0.35
# Generation: 39 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.36666666666666664
# Generation: 40 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0008333333333333333 , Time passed(minutes): 0.3333333333333333
# Generation: 41 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.00125 , Time passed(minutes): 0.35
# Generation: 42 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.00125 , Time passed(minutes): 0.35
# Generation: 43 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0018749999999999995 , Time passed(minutes): 0.3333333333333333
# Generation: 44 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0020833333333333333 , Time passed(minutes): 0.35
# Generation: 45 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0019791666666666664 , Time passed(minutes): 0.35
# Generation: 46 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.36666666666666664
# Generation: 47 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.43333333333333335
# Generation: 48 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.35
# Generation: 49 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.35
# Generation: 50 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.36666666666666664
# Generation: 51 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0014583333333333334 , Time passed(minutes): 0.35
# Generation: 52 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.3333333333333333
# Generation: 53 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.31666666666666665
# Generation: 54 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0018749999999999995 , Time passed(minutes): 0.35
# Generation: 55 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0008333333333333333 , Time passed(minutes): 0.3333333333333333
# Generation: 56 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.38333333333333336
# Generation: 57 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0014583333333333334 , Time passed(minutes): 0.36666666666666664
# Generation: 58 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.36666666666666664
# Generation: 59 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.36666666666666664
# Generation: 60 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.36666666666666664
# Generation: 61 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0015624999999999997 , Time passed(minutes): 0.38333333333333336
# Generation: 62 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.4
# Generation: 63 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.36666666666666664
# Generation: 64 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.35
# Generation: 65 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.00125 , Time passed(minutes): 0.36666666666666664
# Generation: 66 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0014583333333333334 , Time passed(minutes): 0.4
# Generation: 67 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0007291666666666666 , Time passed(minutes): 0.38333333333333336
# Generation: 68 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0015624999999999997 , Time passed(minutes): 0.43333333333333335
# Generation: 69 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002291666666666666 , Time passed(minutes): 0.4166666666666667
# Generation: 70 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0024999999999999996 , Time passed(minutes): 0.4166666666666667
# Generation: 71 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.001354166666666667 , Time passed(minutes): 0.4
# Generation: 72 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002083333333333333 , Time passed(minutes): 0.4
# Generation: 73 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.43333333333333335
# Generation: 74 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0018749999999999995 , Time passed(minutes): 0.4166666666666667
# Generation: 75 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.4166666666666667
# Generation: 76 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.4166666666666667
# Generation: 77 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0016666666666666663 , Time passed(minutes): 0.4
# Generation: 78 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0014583333333333332 , Time passed(minutes): 0.38333333333333336
# Generation: 79 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.35
# Generation: 80 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.36666666666666664
# Generation: 81 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0016666666666666666 , Time passed(minutes): 0.38333333333333336
# Generation: 82 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0026041666666666657 , Time passed(minutes): 0.45
# Generation: 83 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0015624999999999997 , Time passed(minutes): 0.4
# Generation: 84 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002083333333333333 , Time passed(minutes): 0.38333333333333336
# Generation: 85 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0014583333333333332 , Time passed(minutes): 0.38333333333333336
# Generation: 86 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0016666666666666663 , Time passed(minutes): 0.38333333333333336
# Generation: 87 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0017708333333333328 , Time passed(minutes): 0.4
# Generation: 88 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.00125 , Time passed(minutes): 0.4
# Generation: 89 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0014583333333333334 , Time passed(minutes): 0.38333333333333336
# Generation: 90 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0016666666666666666 , Time passed(minutes): 0.4166666666666667
# Generation: 91 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0015624999999999997 , Time passed(minutes): 0.4
# Generation: 92 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0012500000000000002 , Time passed(minutes): 0.36666666666666664
# Generation: 93 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0009375 , Time passed(minutes): 0.38333333333333336
# Generation: 94 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.00125 , Time passed(minutes): 0.36666666666666664
# Generation: 95 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.36666666666666664
# Generation: 96 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0013541666666666665 , Time passed(minutes): 0.36666666666666664
# Generation: 97 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.36666666666666664
# Generation: 98 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.4
# Generation: 99 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0008333333333333333 , Time passed(minutes): 0.36666666666666664
# Generation: 100 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.00125 , Time passed(minutes): 0.36666666666666664
# Generation: 101 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0006249999999999999 , Time passed(minutes): 0.36666666666666664
# Generation: 102 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0011458333333333333 , Time passed(minutes): 0.36666666666666664
# Generation: 103 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.36666666666666664
# Generation: 104 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0014583333333333334 , Time passed(minutes): 0.3333333333333333
# Generation: 105 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.001979166666666666 , Time passed(minutes): 0.36666666666666664
# Generation: 106 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0014583333333333332 , Time passed(minutes): 0.38333333333333336
# Generation: 107 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0014583333333333332 , Time passed(minutes): 0.38333333333333336
# Generation: 108 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.00125 , Time passed(minutes): 0.38333333333333336
# Generation: 109 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002812499999999999 , Time passed(minutes): 0.38333333333333336
# Generation: 110 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0005208333333333333 , Time passed(minutes): 0.36666666666666664
# Generation: 111 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0010416666666666667 , Time passed(minutes): 0.38333333333333336
# Generation: 112 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.00125 , Time passed(minutes): 0.38333333333333336
# Generation: 113 , Max fitness: 0.010416666666666666 , Max donuts: 1 , Average fitness: 0.0014583333333333332 , Time passed(minutes): 0.38333333333333336
# Generation: 114 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.001979166666666666 , Time passed(minutes): 0.4
# Generation: 115 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0018749999999999997 , Time passed(minutes): 0.36666666666666664
# Generation: 116 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0016666666666666666 , Time passed(minutes): 0.4
# Generation: 117 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0028125 , Time passed(minutes): 0.4666666666666667
# Generation: 118 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0015625 , Time passed(minutes): 0.38333333333333336
# Generation: 119 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002291666666666666 , Time passed(minutes): 0.4
# Generation: 120 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0027083333333333326 , Time passed(minutes): 0.4
# Generation: 121 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003125 , Time passed(minutes): 0.4
# Generation: 122 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0028125 , Time passed(minutes): 0.38333333333333336
# Generation: 123 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002291666666666666 , Time passed(minutes): 0.38333333333333336
# Generation: 124 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0034374999999999996 , Time passed(minutes): 0.38333333333333336
# Generation: 125 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0030208333333333337 , Time passed(minutes): 0.36666666666666664
# Generation: 126 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004062500000000002 , Time passed(minutes): 0.38333333333333336
# Generation: 127 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0027083333333333326 , Time passed(minutes): 0.38333333333333336
# Generation: 128 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0034375 , Time passed(minutes): 0.36666666666666664
# Generation: 129 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002916666666666667 , Time passed(minutes): 0.36666666666666664
# Generation: 130 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003229166666666666 , Time passed(minutes): 0.35
# Generation: 131 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003020833333333334 , Time passed(minutes): 0.36666666666666664
# Generation: 132 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0028124999999999995 , Time passed(minutes): 0.35
# Generation: 133 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0019791666666666664 , Time passed(minutes): 0.36666666666666664
# Generation: 134 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002812499999999999 , Time passed(minutes): 0.4
# Generation: 135 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002499999999999999 , Time passed(minutes): 0.36666666666666664
# Generation: 136 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0033333333333333344 , Time passed(minutes): 0.38333333333333336
# Generation: 137 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0036458333333333343 , Time passed(minutes): 0.38333333333333336
# Generation: 138 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0028125 , Time passed(minutes): 0.4
# Generation: 139 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003125 , Time passed(minutes): 0.4
# Generation: 140 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0031250000000000006 , Time passed(minutes): 0.5
# Generation: 141 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004791666666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 142 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003125 , Time passed(minutes): 0.4166666666666667
# Generation: 143 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0023958333333333327 , Time passed(minutes): 0.4166666666666667
# Generation: 144 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0032291666666666666 , Time passed(minutes): 0.43333333333333335
# Generation: 145 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003958333333333334 , Time passed(minutes): 0.43333333333333335
# Generation: 146 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0035416666666666656 , Time passed(minutes): 0.4166666666666667
# Generation: 147 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.004062500000000002 , Time passed(minutes): 0.45
# Generation: 148 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0030208333333333333 , Time passed(minutes): 0.43333333333333335
# Generation: 149 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003333333333333333 , Time passed(minutes): 0.4166666666666667
# Generation: 150 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003333333333333333 , Time passed(minutes): 0.4166666666666667
# Generation: 151 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003645833333333334 , Time passed(minutes): 0.43333333333333335
# Generation: 152 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003333333333333333 , Time passed(minutes): 0.4166666666666667
# Generation: 153 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003333333333333333 , Time passed(minutes): 0.43333333333333335
# Generation: 154 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0031249999999999993 , Time passed(minutes): 0.4
# Generation: 155 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003854166666666668 , Time passed(minutes): 0.43333333333333335
# Generation: 156 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0051041666666666674 , Time passed(minutes): 0.45
# Generation: 157 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002499999999999999 , Time passed(minutes): 0.43333333333333335
# Generation: 158 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0029166666666666664 , Time passed(minutes): 0.45
# Generation: 159 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0032291666666666666 , Time passed(minutes): 0.43333333333333335
# Generation: 160 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0034375000000000013 , Time passed(minutes): 0.43333333333333335
# Generation: 161 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0030208333333333333 , Time passed(minutes): 0.4166666666666667
# Generation: 162 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0028124999999999995 , Time passed(minutes): 0.45
# Generation: 163 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003958333333333333 , Time passed(minutes): 0.43333333333333335
# Generation: 164 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0036458333333333343 , Time passed(minutes): 0.43333333333333335
# Generation: 165 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003020833333333332 , Time passed(minutes): 0.45
# Generation: 166 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003125 , Time passed(minutes): 0.43333333333333335
# Generation: 167 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003958333333333333 , Time passed(minutes): 0.5333333333333333
# Generation: 168 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0029166666666666664 , Time passed(minutes): 0.43333333333333335
# Generation: 169 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0041666666666666675 , Time passed(minutes): 0.4166666666666667
# Generation: 170 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004583333333333335 , Time passed(minutes): 0.43333333333333335
# Generation: 171 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0031250000000000006 , Time passed(minutes): 0.4166666666666667
# Generation: 172 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004479166666666668 , Time passed(minutes): 0.43333333333333335
# Generation: 173 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0033333333333333335 , Time passed(minutes): 0.4
# Generation: 174 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0030208333333333324 , Time passed(minutes): 0.4
# Generation: 175 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002916666666666666 , Time passed(minutes): 0.4166666666666667
# Generation: 176 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0039583333333333345 , Time passed(minutes): 0.45
# Generation: 177 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005208333333333335 , Time passed(minutes): 0.45
# Generation: 178 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000001 , Time passed(minutes): 0.4666666666666667
# Generation: 179 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003958333333333334 , Time passed(minutes): 0.45
# Generation: 180 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0034375000000000013 , Time passed(minutes): 0.43333333333333335
# Generation: 181 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.00510416666666667 , Time passed(minutes): 0.45
# Generation: 182 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004062500000000001 , Time passed(minutes): 0.4166666666666667
# Generation: 183 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0039583333333333345 , Time passed(minutes): 0.43333333333333335
# Generation: 184 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0048958333333333345 , Time passed(minutes): 0.45
# Generation: 185 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004791666666666667 , Time passed(minutes): 0.4666666666666667
# Generation: 186 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005416666666666666 , Time passed(minutes): 0.4666666666666667
# Generation: 187 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0035416666666666674 , Time passed(minutes): 0.43333333333333335
# Generation: 188 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003958333333333335 , Time passed(minutes): 0.45
# Generation: 189 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005312500000000002 , Time passed(minutes): 0.45
# Generation: 190 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005416666666666666 , Time passed(minutes): 0.45
# Generation: 191 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004791666666666667 , Time passed(minutes): 0.43333333333333335
# Generation: 192 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005624999999999998 , Time passed(minutes): 0.43333333333333335
# Generation: 193 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.006354166666666665 , Time passed(minutes): 0.4166666666666667
# Generation: 194 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004479166666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 195 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004583333333333337 , Time passed(minutes): 0.4166666666666667
# Generation: 196 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004062500000000002 , Time passed(minutes): 0.4
# Generation: 197 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0039583333333333345 , Time passed(minutes): 0.4166666666666667
# Generation: 198 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0033333333333333335 , Time passed(minutes): 0.4
# Generation: 199 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 200 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005208333333333332 , Time passed(minutes): 0.5333333333333333
# Generation: 201 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005208333333333335 , Time passed(minutes): 0.43333333333333335
# Generation: 202 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005729166666666667 , Time passed(minutes): 0.43333333333333335
# Generation: 203 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004791666666666669 , Time passed(minutes): 0.43333333333333335
# Generation: 204 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.006145833333333333 , Time passed(minutes): 0.45
# Generation: 205 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.005416666666666669 , Time passed(minutes): 0.43333333333333335
# Generation: 206 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003541666666666667 , Time passed(minutes): 0.43333333333333335
# Generation: 207 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005520833333333332 , Time passed(minutes): 0.43333333333333335
# Generation: 208 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005312500000000002 , Time passed(minutes): 0.4166666666666667
# Generation: 209 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0040625 , Time passed(minutes): 0.4166666666666667
# Generation: 210 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004166666666666667 , Time passed(minutes): 0.43333333333333335
# Generation: 211 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003958333333333333 , Time passed(minutes): 0.43333333333333335
# Generation: 212 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0036458333333333347 , Time passed(minutes): 0.4166666666666667
# Generation: 213 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003541666666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 214 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004479166666666669 , Time passed(minutes): 0.4166666666666667
# Generation: 215 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0038541666666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 216 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0033333333333333327 , Time passed(minutes): 0.4
# Generation: 217 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.004687500000000002 , Time passed(minutes): 0.45
# Generation: 218 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004166666666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 219 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.45
# Generation: 220 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0069791666666666665 , Time passed(minutes): 0.43333333333333335
# Generation: 221 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.4166666666666667
# Generation: 222 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005312500000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 223 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 224 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.4166666666666667
# Generation: 225 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0041666666666666675 , Time passed(minutes): 0.4166666666666667
# Generation: 226 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005416666666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 227 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005416666666666669 , Time passed(minutes): 0.4166666666666667
# Generation: 228 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003750000000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 229 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004166666666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 230 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004583333333333335 , Time passed(minutes): 0.4166666666666667
# Generation: 231 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0032291666666666666 , Time passed(minutes): 0.4
# Generation: 232 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.4166666666666667
# Generation: 233 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0036458333333333347 , Time passed(minutes): 0.4
# Generation: 234 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0036458333333333343 , Time passed(minutes): 0.4
# Generation: 235 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0034375000000000005 , Time passed(minutes): 0.4
# Generation: 236 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0033333333333333335 , Time passed(minutes): 0.4
# Generation: 237 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0037500000000000007 , Time passed(minutes): 0.38333333333333336
# Generation: 238 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.00375 , Time passed(minutes): 0.55
# Generation: 239 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.38333333333333336
# Generation: 240 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003125 , Time passed(minutes): 0.38333333333333336
# Generation: 241 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0034375000000000005 , Time passed(minutes): 0.38333333333333336
# Generation: 242 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004583333333333334 , Time passed(minutes): 0.38333333333333336
# Generation: 243 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004062500000000001 , Time passed(minutes): 0.4
# Generation: 244 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003229166666666666 , Time passed(minutes): 0.38333333333333336
# Generation: 245 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004687500000000001 , Time passed(minutes): 0.4
# Generation: 246 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0036458333333333347 , Time passed(minutes): 0.36666666666666664
# Generation: 247 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0037500000000000007 , Time passed(minutes): 0.38333333333333336
# Generation: 248 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0040625 , Time passed(minutes): 0.38333333333333336
# Generation: 249 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0036458333333333343 , Time passed(minutes): 0.4
# Generation: 250 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0036458333333333343 , Time passed(minutes): 0.38333333333333336
# Generation: 251 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005625 , Time passed(minutes): 0.43333333333333335
# Generation: 252 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004479166666666669 , Time passed(minutes): 0.43333333333333335
# Generation: 253 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005000000000000001 , Time passed(minutes): 0.45
# Generation: 254 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004583333333333335 , Time passed(minutes): 0.43333333333333335
# Generation: 255 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005625 , Time passed(minutes): 0.43333333333333335
# Generation: 256 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005208333333333335 , Time passed(minutes): 0.43333333333333335
# Generation: 257 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003645833333333333 , Time passed(minutes): 0.4166666666666667
# Generation: 258 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0040625 , Time passed(minutes): 0.43333333333333335
# Generation: 259 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005000000000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 260 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004687500000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 261 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004166666666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 262 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0036458333333333343 , Time passed(minutes): 0.4166666666666667
# Generation: 263 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0033333333333333335 , Time passed(minutes): 0.4
# Generation: 264 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.4166666666666667
# Generation: 265 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0048958333333333345 , Time passed(minutes): 0.4166666666666667
# Generation: 266 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005312500000000002 , Time passed(minutes): 0.4166666666666667
# Generation: 267 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003750000000000001 , Time passed(minutes): 0.4166666666666667
# Generation: 268 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004270833333333334 , Time passed(minutes): 0.4166666666666667
# Generation: 269 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004687500000000001 , Time passed(minutes): 0.4166666666666667
# Generation: 270 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.4
# Generation: 271 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.002916666666666667 , Time passed(minutes): 0.38333333333333336
# Generation: 272 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004479166666666668 , Time passed(minutes): 0.4166666666666667
# Generation: 273 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0041666666666666675 , Time passed(minutes): 0.4166666666666667
# Generation: 274 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0039583333333333345 , Time passed(minutes): 0.4166666666666667
# Generation: 275 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004270833333333335 , Time passed(minutes): 0.4166666666666667
# Generation: 276 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0041666666666666675 , Time passed(minutes): 0.4
# Generation: 277 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.004062499999999999 , Time passed(minutes): 0.4
# Generation: 278 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005312499999999999 , Time passed(minutes): 0.4166666666666667
# Generation: 279 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0044791666666666695 , Time passed(minutes): 0.4166666666666667
# Generation: 280 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004687500000000001 , Time passed(minutes): 0.4166666666666667
# Generation: 281 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005208333333333335 , Time passed(minutes): 0.4166666666666667
# Generation: 282 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0037500000000000007 , Time passed(minutes): 0.4
# Generation: 283 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004375000000000003 , Time passed(minutes): 0.4166666666666667
# Generation: 284 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004166666666666667 , Time passed(minutes): 0.6666666666666666
# Generation: 285 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0032291666666666666 , Time passed(minutes): 0.4
# Generation: 286 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004375 , Time passed(minutes): 0.4
# Generation: 287 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0041666666666666675 , Time passed(minutes): 0.43333333333333335
# Generation: 288 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0035416666666666674 , Time passed(minutes): 0.4
# Generation: 289 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.0055208333333333325 , Time passed(minutes): 0.4166666666666667
# Generation: 290 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004895833333333334 , Time passed(minutes): 0.4166666666666667
# Generation: 291 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0053125 , Time passed(minutes): 0.45
# Generation: 292 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006249999999999997 , Time passed(minutes): 0.45
# Generation: 293 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005208333333333335 , Time passed(minutes): 0.45
# Generation: 294 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005312500000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 295 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004479166666666669 , Time passed(minutes): 0.43333333333333335
# Generation: 296 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004687500000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 297 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005312500000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 298 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0053125 , Time passed(minutes): 0.45
# Generation: 299 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 300 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 301 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004895833333333336 , Time passed(minutes): 0.43333333333333335
# Generation: 302 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0046875 , Time passed(minutes): 0.43333333333333335
# Generation: 303 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0044791666666666695 , Time passed(minutes): 0.4166666666666667
# Generation: 304 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000001 , Time passed(minutes): 0.45
# Generation: 305 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.00479166666666667 , Time passed(minutes): 0.4166666666666667
# Generation: 306 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005937499999999999 , Time passed(minutes): 0.43333333333333335
# Generation: 307 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005729166666666667 , Time passed(minutes): 0.45
# Generation: 308 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005937499999999999 , Time passed(minutes): 0.4666666666666667
# Generation: 309 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004062500000000001 , Time passed(minutes): 0.45
# Generation: 310 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004687500000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 311 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0051041666666666674 , Time passed(minutes): 0.43333333333333335
# Generation: 312 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005416666666666668 , Time passed(minutes): 0.4666666666666667
# Generation: 313 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003645833333333333 , Time passed(minutes): 0.45
# Generation: 314 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.005000000000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 315 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005312500000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 316 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005208333333333334 , Time passed(minutes): 0.43333333333333335
# Generation: 317 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004791666666666668 , Time passed(minutes): 0.43333333333333335
# Generation: 318 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 319 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004687500000000001 , Time passed(minutes): 0.4666666666666667
# Generation: 320 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004791666666666669 , Time passed(minutes): 0.43333333333333335
# Generation: 321 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0053125 , Time passed(minutes): 0.4166666666666667
# Generation: 322 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0035416666666666665 , Time passed(minutes): 0.4166666666666667
# Generation: 323 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005520833333333333 , Time passed(minutes): 0.43333333333333335
# Generation: 324 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003541666666666667 , Time passed(minutes): 0.4166666666666667
# Generation: 325 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0051041666666666674 , Time passed(minutes): 0.48333333333333334
# Generation: 326 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0035416666666666656 , Time passed(minutes): 0.45
# Generation: 327 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005208333333333335 , Time passed(minutes): 0.45
# Generation: 328 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004270833333333335 , Time passed(minutes): 0.43333333333333335
# Generation: 329 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003958333333333334 , Time passed(minutes): 0.4166666666666667
# Generation: 330 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0039583333333333345 , Time passed(minutes): 0.4166666666666667
# Generation: 331 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004062500000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 332 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003750000000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 333 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0051041666666666674 , Time passed(minutes): 0.43333333333333335
# Generation: 334 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004895833333333334 , Time passed(minutes): 0.4166666666666667
# Generation: 335 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0048958333333333345 , Time passed(minutes): 0.4166666666666667
# ...
# Generation: 371 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.43333333333333335
# Generation: 372 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.00510416666666667 , Time passed(minutes): 0.43333333333333335
# Generation: 373 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0046875000000000016 , Time passed(minutes): 0.4166666666666667
# Generation: 374 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005520833333333333 , Time passed(minutes): 0.43333333333333335
# Generation: 375 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0051041666666666674 , Time passed(minutes): 0.43333333333333335
# Generation: 376 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004791666666666668 , Time passed(minutes): 0.43333333333333335
# Generation: 377 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.0044791666666666695 , Time passed(minutes): 0.45
# Generation: 378 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004583333333333335 , Time passed(minutes): 0.45
# Generation: 379 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005416666666666669 , Time passed(minutes): 0.4666666666666667
# Generation: 380 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006979166666666664 , Time passed(minutes): 0.4666666666666667
# Generation: 381 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004583333333333334 , Time passed(minutes): 0.43333333333333335
# Generation: 382 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005208333333333334 , Time passed(minutes): 0.4666666666666667
# Generation: 383 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004583333333333335 , Time passed(minutes): 0.45
# Generation: 384 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004687500000000001 , Time passed(minutes): 0.45
# Generation: 385 , Max fitness: 0.052083333333333336 , Max donuts: 5 , Average fitness: 0.006041666666666668 , Time passed(minutes): 0.45
# Generation: 386 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004791666666666669 , Time passed(minutes): 0.43333333333333335
# Generation: 387 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.007395833333333327 , Time passed(minutes): 0.45
# Generation: 388 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.005104166666666667 , Time passed(minutes): 0.4166666666666667
# Generation: 389 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.006562499999999998 , Time passed(minutes): 0.4666666666666667
# Generation: 390 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005729166666666667 , Time passed(minutes): 0.45
# Generation: 391 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005937499999999999 , Time passed(minutes): 0.45
# Generation: 392 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005416666666666666 , Time passed(minutes): 0.43333333333333335
# Generation: 393 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0056250000000000015 , Time passed(minutes): 0.45
# Generation: 394 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004895833333333335 , Time passed(minutes): 0.43333333333333335
# Generation: 395 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004687500000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 396 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003645833333333334 , Time passed(minutes): 0.45
# Generation: 397 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005833333333333332 , Time passed(minutes): 0.45
# Generation: 398 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005833333333333334 , Time passed(minutes): 0.43333333333333335
# Generation: 399 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.006666666666666665 , Time passed(minutes): 0.48333333333333334
# Generation: 400 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 401 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005937500000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 402 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0053125 , Time passed(minutes): 0.4166666666666667
# Generation: 403 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006354166666666668 , Time passed(minutes): 0.45
# Generation: 404 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.00583333333333333 , Time passed(minutes): 1.9
# Generation: 405 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005208333333333334 , Time passed(minutes): 0.65
# Generation: 406 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0059375 , Time passed(minutes): 0.6
# Generation: 407 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004583333333333335 , Time passed(minutes): 0.55
# Generation: 408 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006979166666666663 , Time passed(minutes): 0.55
# Generation: 409 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006145833333333333 , Time passed(minutes): 0.55
# Generation: 410 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005416666666666666 , Time passed(minutes): 0.5666666666666667
# Generation: 411 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004895833333333335 , Time passed(minutes): 0.55
# Generation: 412 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005937500000000001 , Time passed(minutes): 0.5333333333333333
# Generation: 413 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.005312500000000002 , Time passed(minutes): 0.5166666666666667
# Generation: 414 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005000000000000002 , Time passed(minutes): 0.5
# Generation: 415 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004583333333333337 , Time passed(minutes): 0.55
# Generation: 416 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006041666666666667 , Time passed(minutes): 0.5333333333333333
# Generation: 417 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004895833333333335 , Time passed(minutes): 0.5333333333333333
# Generation: 418 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005729166666666669 , Time passed(minutes): 0.5333333333333333
# Generation: 419 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004895833333333335 , Time passed(minutes): 0.5166666666666667
# Generation: 420 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004895833333333335 , Time passed(minutes): 0.5
# Generation: 421 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0058333333333333345 , Time passed(minutes): 0.5
# Generation: 422 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004791666666666669 , Time passed(minutes): 0.48333333333333334
# Generation: 423 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005312500000000002 , Time passed(minutes): 0.5333333333333333
# Generation: 424 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005208333333333335 , Time passed(minutes): 0.5
# Generation: 425 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.00510416666666667 , Time passed(minutes): 0.48333333333333334
# Generation: 426 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004166666666666666 , Time passed(minutes): 0.45
# Generation: 427 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003854166666666668 , Time passed(minutes): 0.6166666666666667
# Generation: 428 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0059375 , Time passed(minutes): 0.48333333333333334
# Generation: 429 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005312500000000001 , Time passed(minutes): 0.4666666666666667
# Generation: 430 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.007187499999999999 , Time passed(minutes): 0.48333333333333334
# Generation: 431 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004270833333333333 , Time passed(minutes): 0.43333333333333335
# Generation: 432 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.006145833333333333 , Time passed(minutes): 0.4666666666666667
# Generation: 433 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.006041666666666664 , Time passed(minutes): 0.48333333333333334
# Generation: 434 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004895833333333336 , Time passed(minutes): 0.4666666666666667
# Generation: 435 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005833333333333333 , Time passed(minutes): 0.4666666666666667
# Generation: 436 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004895833333333336 , Time passed(minutes): 0.5333333333333333
# Generation: 437 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0058333333333333345 , Time passed(minutes): 0.45
# Generation: 438 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004895833333333336 , Time passed(minutes): 0.45
# Generation: 439 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.003854166666666667 , Time passed(minutes): 0.43333333333333335
# Generation: 440 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0046875000000000016 , Time passed(minutes): 0.45
# Generation: 441 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.005729166666666667 , Time passed(minutes): 0.4666666666666667
# Generation: 442 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004375000000000001 , Time passed(minutes): 0.45
# Generation: 443 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003541666666666667 , Time passed(minutes): 0.43333333333333335
# Generation: 444 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004687500000000001 , Time passed(minutes): 0.45
# Generation: 445 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005520833333333335 , Time passed(minutes): 0.45
# Generation: 446 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.0046875000000000016 , Time passed(minutes): 0.43333333333333335
# Generation: 447 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.00583333333333333 , Time passed(minutes): 0.45
# Generation: 448 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004062500000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 449 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006458333333333332 , Time passed(minutes): 0.45
# Generation: 450 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005625 , Time passed(minutes): 0.45
# Generation: 451 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006249999999999999 , Time passed(minutes): 0.4666666666666667
# Generation: 452 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004270833333333336 , Time passed(minutes): 0.43333333333333335
# Generation: 453 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006145833333333334 , Time passed(minutes): 0.45
# Generation: 454 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005208333333333334 , Time passed(minutes): 0.43333333333333335
# Generation: 455 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.006041666666666665 , Time passed(minutes): 0.4666666666666667
# Generation: 456 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005208333333333336 , Time passed(minutes): 0.45
# Generation: 457 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005104166666666668 , Time passed(minutes): 0.45
# Generation: 458 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005520833333333335 , Time passed(minutes): 0.4666666666666667
# Generation: 459 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005833333333333334 , Time passed(minutes): 0.4666666666666667
# Generation: 460 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005208333333333335 , Time passed(minutes): 0.45
# Generation: 461 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005312500000000001 , Time passed(minutes): 0.45
# Generation: 462 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0051041666666666674 , Time passed(minutes): 0.43333333333333335
# Generation: 463 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006145833333333333 , Time passed(minutes): 0.45
# Generation: 464 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004791666666666667 , Time passed(minutes): 0.43333333333333335
# Generation: 465 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004791666666666668 , Time passed(minutes): 0.43333333333333335
# Generation: 466 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005729166666666666 , Time passed(minutes): 0.45
# Generation: 467 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0064583333333333316 , Time passed(minutes): 0.45
# Generation: 468 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005416666666666665 , Time passed(minutes): 0.4666666666666667
# Generation: 469 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004895833333333336 , Time passed(minutes): 0.43333333333333335
# Generation: 470 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0059375 , Time passed(minutes): 0.45
# Generation: 471 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.00572916666666667 , Time passed(minutes): 0.45
# Generation: 472 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005000000000000002 , Time passed(minutes): 0.43333333333333335
# Generation: 473 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005416666666666666 , Time passed(minutes): 0.43333333333333335
# Generation: 474 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0055208333333333325 , Time passed(minutes): 0.45
# Generation: 475 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004479166666666668 , Time passed(minutes): 0.45
# Generation: 476 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.005312500000000001 , Time passed(minutes): 0.45
# Generation: 477 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.0055208333333333325 , Time passed(minutes): 0.45
# Generation: 478 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.0048958333333333345 , Time passed(minutes): 0.45
# Generation: 479 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005312500000000001 , Time passed(minutes): 0.45
# Generation: 480 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.004583333333333335 , Time passed(minutes): 0.45
# Generation: 481 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.003750000000000001 , Time passed(minutes): 2.15
# Generation: 482 , Max fitness: 0.020833333333333332 , Max donuts: 2 , Average fitness: 0.005000000000000002 , Time passed(minutes): 0.5333333333333333
# Generation: 483 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.005729166666666671 , Time passed(minutes): 0.5166666666666667
# Generation: 484 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.004895833333333336 , Time passed(minutes): 0.5
# Generation: 485 , Max fitness: 0.041666666666666664 , Max donuts: 4 , Average fitness: 0.005312500000000001 , Time passed(minutes): 0.48333333333333334
# Generation: 486 , Max fitness: 0.03125 , Max donuts: 3 , Average fitness: 0.006562499999999996 , Time passed(minutes): 0.5

# %%
plt.plot(mean_fitness)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7c20a7e0c83> in <module>
# ----> 1 plt.plot(mean_fitness)
#
# NameError: name 'plt' is not defined

# %%
i = 1
for model in population:
    filename = '250_population/'+str(i)+'_organism.h5'
    model.save(filename)
    i+=1

# %% [markdown]
# OBSERVATION:
# Up = (0,-1)<br>
# Up-left = (-1,-1)<br>
# Up-right = (1,-1)<br>
# Right = (1,0)<br>
# Left = (-1,0)<br>
# Down = (0,1)<br>
# Down-left = (-1, 1)<br>
# Down-right = (1,1)<br><br>
